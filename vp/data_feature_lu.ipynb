# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
goods_train = pd.read_table('./vp_data/vp_data/goods_train.txt',header=None)   #2004581 spu  6955 brand  49 cat
user_action_train = pd.read_table('./vp_data/vp_data/user_action_train.txt',header=None)# 56172886 click 196030 user  1920715 spu  48 cat 6497 brand  83 date 
user_action_test_items = pd.read_table('./vp_data/vp_data/user_action_test_items.txt',header=None)

# %%
a = user_action_train.groupby(['user_id','spu_id','date'],as_index = False).size()

# %%
user_action_train[user_action_train.index==c]
# Out:
#    user_id  spu_id  action_type   date
# 1   320510  839213            0  03-10

# %%
c=a[a>1].index

# %%
len(user_action_train['date'].unique())
# Out:
# 83

# %%
goods_train.columns=['spu_id','brand_id','cat_id']
user_action_train.columns = ['user_id','spu_id','action_type','date']
user_action_test_items,columns = ['user_id','spu_id']

# %%
user_goods_action_train = pd.merge(user_action_train,goods_train, how='left', on='spu_id')
user_goods_action_train
# Out:
#           user_id   spu_id  action_type   date  brand_id  cat_id
# 0          522945   338312            0  03-28  10005188    1012
# 1          320510   839213            0  03-10  10010631     271
# 2          314210   369282            0  01-05  10001351     311
# 3          381441   730484            0  01-05  10000866     311
# 4          168858   902515            0  03-10  10028088     297
# 5          270694   953270            0  01-30  10000223    1056
# 6          334640  1130939            0  03-27  10012546     271
# 7          228326  1080895            0  03-22  10020201     311
# 8          253864  2038905            0  03-23  10026544     311
# 9          491107  1213935            0  01-17  10010670     311
# 10         301610   523966            0  02-12  10015807   28008
# 11         397506  1443952            0  03-04  10000223    1056
# 12         566956   960691            0  02-12  10001160     337
# 13         555323  2102754            0  03-17  10003503     297
# 14         359638   880522            0  03-01  10004555     311
# 15         488947    50140            0  01-20  10026233   28008
# 16         139495  1319316            0  02-13  10000601     311
# 17           3661   414312            0  02-01  10020688     311
# 18         431099  1546003            0  02-01  10014501     311
# 19         480577  1835465            0  02-15  10027050    1056
# 20         154840  1330378            0  03-20  10004900     271
# 21         184136   888835            0  02-09  10007612     311
# 22         395166   498414            0  03-04  10004119   28006
# 23         607389   157900            0  01-11  10000957     311
# 24         143433  1949994            0  01-22  10001050    7469
# 25         454004   311406            0  03-24  10000601     311
# 26         220946  1349542            0  02-14  10020636     271
# 27         477157  1460975            0  02-21  10014265    7470
# 28         447322   553859            0  02-09  10024288     311
# 29         192731  1640192            0  01-14  10015070     271
# ...           ...      ...          ...    ...       ...     ...
# 56172856   275350  1733838            0  02-18  10012855    1056
# 56172857   549561  1922130            0  01-05  10012724   28006
# 56172858   484355  1468100            0  01-19  10014937     311
# 56172859   273595  1124834            0  02-11  10026064     311
# 56172860   618097    28032            0  03-21  10020640     311
# 56172861   238157   153604            0  01-10  10006562     311
# 56172862   305275  1394971            0  02-19  10015060     311
# 56172863     2646   652495            0  02-22  10005711     311
# 56172864   449997   638081            0  01-17  10011806     311
# 56172865   185461   752598            0  03-30  10003862     311
# 56172866   530278   994157            0  03-06  10013584     297
# 56172867   527893   370997            0  03-27  10010317   28006
# 56172868   193651   555229            0  03-13  10005410     311
# 56172869   413884  1042353            0  03-10  10015230    7469
# 56172870   110085  1519454            0  02-06  10015070     271
# 56172871   531808   949607            0  03-27  10022840     311
# 56172872   252872  1223666            0  02-21  10014762     271
# 56172873   340511  1122383            0  03-30  10000737     311
# 56172874   316750   656137            0  01-30  10000281     297
# 56172875   421017  1054531            0  03-24  10020209     311
# 56172876   608219  1376437            0  03-05  10011806     311
# 56172877   519163   602413            0  03-23  10004256     271
# 56172878   385331  1065579            0  01-10  10000651     311
# 56172879    32279  1283268            0  01-16  10014090   28006
# 56172880   385016   855179            0  02-12  10012782     680
# 56172881   254177  1434084            0  02-01  10004603     311
# 56172882   381371   512332            0  02-17  10025733   73741
# 56172883   236357   966857            0  02-09  10007316     311
# 56172884    44812   967277            0  03-16  10016305     311
# 56172885   467862   483871            0  03-24  10004555     311
#
# [56172886 rows x 6 columns]

# %%
#将日期离散化（0-83）
date_set = user_goods_action_train['date'].drop_duplicates().sort_values().values
date ={'date':date_set,'date_num':range(83)}
date_df = pd.DataFrame(date)
user_goods_action_train = pd.merge(user_goods_action_train,date_df, how='left', on='date')
user_goods_action_train
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-a74febf5886f> in <module>()
#       2 date_set = user_goods_action_train['date'].drop_duplicates().sort_values().values
#       3 date ={'date':date_set,'date_num':range(84)}
# ----> 4 date_df = pd.DataFrame(date)
#       5 user_goods_action_train = pd.merge(user_goods_action_train,date_df, how='left', on='date')
#       6 user_goods_action_train
#
# C:\Users\luguangcheng\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     222                                  dtype=dtype, copy=copy)
#     223         elif isinstance(data, dict):
# --> 224             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     225         elif isinstance(data, ma.MaskedArray):
#     226             import numpy.ma.mrecords as mrecords
#
# C:\Users\luguangcheng\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _init_dict(self, data, index, columns, dtype)
#     358             arrays = [data[k] for k in keys]
#     359
# --> 360         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     361
#     362     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# C:\Users\luguangcheng\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    5229     # figure out the index, if necessary
#    5230     if index is None:
# -> 5231         index = extract_index(arrays)
#    5232     else:
#    5233         index = _ensure_index(index)
#
# C:\Users\luguangcheng\Anaconda2\lib\site-packages\pandas\core\frame.pyc in extract_index(data)
#    5277             lengths = list(set(raw_lengths))
#    5278             if len(lengths) > 1:
# -> 5279                 raise ValueError('arrays must all be same length')
#    5280
#    5281             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
#将数据按时间排序
user_goods_action_train_sort = user_goods_action_train.sort_values(by = 'date_num')
user_goods_action_train_sort
# Out:
#           user_id   spu_id  action_type   date  brand_id  cat_id  date_num
# 32538053   207091  1098103            0     01  10000777     311         0
# 5958439    356293  2011376            0  01-03  10023064     311         1
# 29045969    17647  1904481            0  01-03  10000733     311         1
# 20411375   232753  1792992            0  01-03  10011649     311         1
# 20411376   359295   653250            0  01-03  10025367   73741         1
# 12561370   618025   553471            0  01-03  10020688     311         1
# 29045931   545549   649148            0  01-03  10004090     356         1
# 20411403     2800  1420926            0  01-03  10000292     311         1
# 17113994   471129  1526819            0  01-03  10020688     311         1
# 9817837    460239  2102839            0  01-03  10000547     311         1
# 5958452    136848  1692480            0  01-03  10010580     337         1
# 1715213    603569   544261            0  01-03  10013861     311         1
# 29045784    50428   524999            0  01-03  10010460     311         1
# 9817813    217641   226731            0  01-03  10022267    7469         1
# 5958385      1683  2014557            0  01-03  10000126     337         1
# 9817804    376043   472853            0  01-03  10000799     311         1
# 17113967   180130  1819698            1  01-03  10004116     337         1
# 17113964   315582  1395892            0  01-03  10013861     311         1
# 29045720   430378  1083586            0  01-03  10024925     311         1
# 1715254    186749   647110            0  01-03  10010460     271         1
# 1715257    398387   290557            0  01-03  10015652   28007         1
# 29045785   334899  1135832            0  01-03  10000646     311         1
# 20411529   353517  2024727            0  01-03  10010265     311         1
# 5958454    135363   942182            0  01-03  10006562     337         1
# 20411340   188585   133117            0  01-03  10000223    1056         1
# 29046439   150902   306610            0  01-03  10000777     337         1
# 29046427   626765   274371            0  01-03  10021212     311         1
# 29046386     4992    23574            0  01-03  10020688     311         1
# 29046381   304673  1974872            0  01-03  10000737     337         1
# 12561193   478583   855113            0  01-03  10022202    7469         1
# ...           ...      ...          ...    ...       ...     ...       ...
# 20048080   450914  1249304            0  03-31  10015042     271        83
# 20047925    52840    64581            0  03-31  10010243    7470        83
# 20047767   565655   560101            0  03-31  10000351     311        83
# 6137203    323766  1436282            0  03-31  10016642   42067        83
# 6137207    348359   224031            0  03-31  10015864     311        83
# 6137221    507706   303266            0  03-31  10020415     680        83
# 20048618   597903   988104            0  03-31  10020913     311        83
# 20048623   259408   864581            0  03-31  10024588     609        83
# 20048676    95371   312467            0  03-31  10015864     311        83
# 20048759    70530  1102193            0  03-31  10000434    1056        83
# 402499     437696   446678            0  03-31  10004582     311        83
# 402493     140737  1176629            0  03-31  10000737     311        83
# 6136310     85832  1109010            0  03-31  10000223    1056        83
# 20049562   448756   433119            0  03-31  10003656     311        83
# 20049502    13173  1690328            0  03-31  10010306    1012        83
# 6136379    271932    90264            0  03-31  10014935     311        83
# 20049337   475324   688983            0  03-31  10000223    1056        83
# 20049305   260625   640909            0  03-31  10001348     297        83
# 20047525   364446  1137735            0  03-31  10022244     271        83
# 20049207    58617  1960200            0  03-31  10005866    1012        83
# 6136562    306545   988018            0  03-31  10012316   73741        83
# 6136571     65252  1971060            0  03-31  10005725    1056        83
# 6136584    470685   410206            0  03-31  10000223    1056        83
# 6136608     96032  2082564            0  03-31  10000494     271        83
# 6136620    364933   153048            0  03-31  10014936     311        83
# 20048915   372661  1395821            0  03-31  10010579     311        83
# 6136672     66470  1251121            0  03-31  10013882     311        83
# 20048785   523818  1879036            0  03-31  10004895   73741        83
# 20049196   560801   637557            0  03-31  10000363   28005        83
# 5358386    341671   803609            0  03-31  10000856    1012        83
#
# [32538054 rows x 7 columns]

# %%
#用于生成与用户相关的特征
def get_user_feature(df, start_date, end_date):
    df = df[(df['date_num'] >= start_date) & (df['date_num'] < end_date)]
    #用户购买量——buy
    user_feature = df[['user_id','action_type']].groupby('user_id',as_index=False).sum()
    user_feature.rename(columns={'action_type':'buy'}, inplace = True)
    #用户点击量——user_click
    click = df.groupby('user_id',as_index=False).size()
    click.index = range(len(click))
    user_feature['user_click'] = click
    #用户购买率——buy_click_ratio
    user_feature['buy_click_ratio'] = user_feature['buy']/user_feature['user_click']
    #计算用户最早与最后交互时间与预测时间的间隔——user_first_action_date、user_last_action_date
    df_first = df[['user_id','date_num']].drop_duplicates(['user_id'])
    df_last = df[['user_id','date_num']].drop_duplicates(['user_id'], keep='last')    
    df_first['user_first_action_date'] = end_date - df_first.loc[:,'date_num']
    df_last['user_last_action_date'] = end_date - df_last['date_num']
    del df_first['date_num']
    del df_last['date_num']
    user_feature = pd.merge(user_feature,df_first,how='left', on='user_id')
    user_feature = pd.merge(user_feature,df_last,how='left', on='user_id')
    #计算隔天购买数——buy_getian
    df_buy = df[df['action_type']==1]
    df_buy = df_buy[['user_id','spu_id']]
    df_buy_act = pd.merge(df_buy, df, how='left', on=['user_id','spu_id'])
    df_buy_act = df_buy_act[['user_id','spu_id','action_type']]
    df_buy_act = df_buy_act.drop_duplicates(['user_id','spu_id'])
    df_buy_act = df_buy_act[['user_id','action_type']].groupby(['user_id'],as_index=False).sum()
    user_feature = pd.merge(user_feature,df_buy_act,how = 'left',on='user_id')
    user_feature = user_feature.fillna(0)
    user_feature['buy_getian']= user_feature['buy']- user_feature['action_type']
    #隔天购买率——buy_getian_ratio
    user_feature['buy_getian_ratio'] =  user_feature['buy_getian']/user_feature['buy']
    del user_feature['action_type']
    user_feature = user_feature.fillna(0)
    return user_feature

# %%
#用于生成与商品相关的特征
def get_spu_feature(df, start_date, end_date):
    df = df[(df['date_num'] >= start_date) & (df['date_num'] < end_date)]
    #商品购买量——sell
    spu_feature = df[['spu_id','action_type']].groupby('spu_id',as_index=False).sum()
    spu_feature.rename(columns={'action_type':'sell'}, inplace = True)
    #商品点击量——spu_click
    spu_click = df.groupby('spu_id',as_index=False).size()
    spu_click.index = range(len(spu_click))
    spu_feature['spu_click'] = spu_click
    #商品购买率——sell_click_ratio
    spu_feature['sell_click_ratio'] = spu_feature['sell']/spu_feature['spu_click']
    #计算商品最早与最后交互时间与预测时间的间隔——spu_first_action_date、spu_last_action_date
    df_first = df[['spu_id','date_num']].drop_duplicates(['spu_id'])
    df_last = df[['spu_id','date_num']].drop_duplicates(['spu_id'], keep='last')    
    df_first['spu_first_action_date'] = end_date - df_first.loc[:,'date_num']
    df_last['spu_last_action_date'] = end_date - df_last['date_num']
    del df_first['date_num']
    del df_last['date_num']
    spu_feature = pd.merge(spu_feature,df_first,how='left', on='spu_id')
    spu_feature = pd.merge(spu_feature,df_last,how='left', on='spu_id')
    #计算商品隔天被购买数——spu_sell_getian
    df_buy = df[df['action_type']==1]
    df_buy = df_buy[['user_id','spu_id']]
    df_buy_act = pd.merge(df_buy, df, how='left', on=['user_id','spu_id'])
    df_buy_act = df_buy_act[['user_id','spu_id','action_type']]
    df_buy_act = df_buy_act.drop_duplicates(['user_id','spu_id'])
    df_buy_act = df_buy_act[['spu_id','action_type']].groupby(['spu_id'],as_index=False).sum()
    spu_feature = pd.merge(spu_feature,df_buy_act,how = 'left',on='spu_id')
    spu_feature = spu_feature.fillna(0)
    spu_feature['spu_sell_getian']= spu_feature['sell']- spu_feature['action_type']
    #商品隔天被购买率——spu_sell_getian_ratio
    spu_feature['spu_sell_getian_ratio'] =  spu_feature['spu_sell_getian']/spu_feature['sell']
    del spu_feature['action_type']
    return spu_feature

# %%
a= get_featu

# %%
#用于生成与类别（cate）相关的特征
def get_cat_feature(df, start_date, end_date):
    df = df[(df['date_num'] >= start_date) & (df['date_num'] < end_date)]
    #类别购买量——cat_sell
    cat_feature = df[['cat_id','action_type']].groupby('cat_id',as_index=False).sum()
    cat_feature.rename(columns={'action_type':'cat_sell'}, inplace = True)
    #类别点击量——cat_click
    cat_click = df.groupby('cat_id',as_index=False).size()
    cat_click.index = range(len(cat_click))
    cat_feature['cat_click'] = cat_click
    #类别购买率——cat_sell_click_ratio
    cat_feature['cat_sell_click_ratio'] = cat_feature['cat_sell']/cat_feature['cat_click']
    #计算品类最早与最后交互时间与预测时间的间隔——cat_first_action_date、cat_last_action_date
    df_first = df[['cat_id','date_num']].drop_duplicates(['cat_id'])
    df_last = df[['cat_id','date_num']].drop_duplicates(['cat_id'], keep='last')    
    df_first['cat_first_action_date'] = end_date - df_first.loc[:,'date_num']
    df_last['cat_last_action_date'] = end_date - df_last['date_num']
    del df_first['date_num']
    del df_last['date_num']
    cat_feature = pd.merge(cat_feature,df_first,how='left', on='cat_id')
    cat_feature = pd.merge(cat_feature,df_last,how='left', on='cat_id')
    ##计算类别隔天被购买数——cat_sell_getian
    df_buy = df[df['action_type']==1]
    df_buy = df_buy[['user_id','spu_id']]
    df_buy_act = pd.merge(df_buy, df, how='left', on=['user_id','spu_id'])
    df_buy_act = df_buy_act[['user_id','spu_id','cat_id','action_type']]
    df_buy_act = df_buy_act.drop_duplicates(['user_id','spu_id'])
    df_buy_act = df_buy_act[['cat_id','action_type']].groupby(['cat_id'],as_index=False).sum()
    cat_feature = pd.merge(cat_feature,df_buy_act,how = 'left',on='cat_id')
    cat_feature = cat_feature.fillna(0)
    cat_feature['cat_sell_getian']= cat_feature['cat_sell']- cat_feature['action_type']
    #类别隔天购买率——cat_sell_getian_ratio
    cat_feature['cat_sell_getian_ratio'] =  cat_feature['cat_sell_getian']/cat_feature['cat_sell']
    del cat_feature['action_type']
    cat_feature = cat_feature.fillna(0)
    return cat_feature

# %%
######             以下请无视！！！！！！！！！！！！！！！！！#####################
#计算用户最早与最后交互时间与预测时间的间隔()
df = user_goods_action_train_sort
df = df[(df['date_num'] >= 1) & (df['date_num'] < 3)]
df = df[['user_id','date_num']]
df_first = df.drop_duplicates(['user_id'])
df_last = df.drop_duplicates(['user_id'], keep='last')
end_date =3
df_first['user_first_action_date'] = end_date - df_first.loc[:,'date_num']
df_last['user_last_action_date'] = end_date - df_last['date_num']
del df_first['date_num']
del df_last['date_num']
df_last
# Out:
# C:\Users\luguangcheng\Anaconda2\lib\site-packages\ipykernel\__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\luguangcheng\Anaconda2\lib\site-packages\ipykernel\__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#           user_id  user_last_action_date
# 20412646   548061                      2
# 9820225    278052                      2
# 20406183   272768                      2
# 12557570   138147                      2
# 12559759   573834                      2
# 17115152   298387                      2
# 1712018    290295                      2
# 9814314     70917                      2
# 20420198   240711                      2
# 1725694    160063                      2
# 17107293   648469                      2
# 12570235   267480                      2
# 12570574   330457                      2
# 20423084   496081                      2
# 9816087    628746                      2
# 20414855   335155                      2
# 9816347    545316                      2
# 1721158     78518                      2
# 29035847   571104                      2
# 12566873   606289                      2
# 9826210     70294                      2
# 20391893   195445                      2
# 1698670    186645                      2
# 7573322    135457                      2
# 20394401   618981                      2
# 9824979    123781                      2
# 1700939    230854                      2
# 17127195   175768                      2
# 12543653   545991                      2
# 29083472   609233                      2
# ...           ...                    ...
# 7156813    515297                      1
# 785884     352835                      1
# 6612993    231127                      1
# 18843631    22966                      1
# 6731260    523997                      1
# 11362195   183577                      1
# 11110265   534208                      1
# 30977900    24890                      1
# 10329667   559444                      1
# 11219505   299383                      1
# 19173425   226365                      1
# 7262165    595890                      1
# 31203317   283491                      1
# 10297819   379425                      1
# 19067375   446310                      1
# 7214497    622023                      1
# 7253093    215368                      1
# 10524891   172909                      1
# 6770427    422253                      1
# 31101357   406487                      1
# 17733114   247187                      1
# 6662509    198959                      1
# 7156423    125660                      1
# 10405296   478306                      1
# 11221591   279259                      1
# 461567     528102                      1
# 6743412    628358                      1
# 31497758   443702                      1
# 6533493    624544                      1
# 31206056   171836                      1
#
# [70449 rows x 2 columns]

# %%
#计算用户最早与最后交互时间与预测时间的间隔
df = user_goods_action_train_sort
df = df[(df['date_num'] >= 1) & (df['date_num'] < 3)]
end_date = 3
user_id = df['user_id'].unique()
print len(user_id)
first_action_data = pd.Series(index=user_id)
last_action_data = pd.Series(index=user_id)
for i in user_id:
    first_action_data[i] = end_date - df[df['user_id'] == i].head(1).date_num.values
    last_action_data[i] = end_date - df[df['user_id'] == i].tail(1).date_num.values
    print 'done'
df['user_first_action_data'] = first_action_data
df['user_last_action_data'] = last_action_data
df
# Out:
# 70449
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done

# %%
#计算用户隔天购买次数
df_buy = user_action_train[user_action_train['action_type']==1]
df_buy = df_buy[['user_id','spu_id']]
df_buy = df_buy.drop_duplicates()
user_id_set = df_buy['user_id'].unique()
buy_getian = pd.Series(index = user_id_set)
for i in user_id_set:
    spu_id_set = df_buy[df_buy['user_id']==i].spu_id.unique()
    count = 0
    for j in spu_id_set:
        act = user_action_train[(user_action_train['user_id']==1) & (user_action_train['spu_id']==j)].sort_values(by='date')
        if act.head(1).action_type.values == 0:
            count = count + 1
    buy_getian[i] = count
user_feature['buy_getian'] = buy_getian
user_feature
#df_buy_act = user_action_train[user_action_train[['user_id','spu_id']]== df_buy.values].sort_values(by='a')
# df_buy = pd.merge(df_buy, user_action_train, how='left', on=['user_id','spu_id'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-1c372be03084> in <module>()
#       8     count = 0
#       9     for j in spu_id_set:
# ---> 10         act = user_action_train[(user_action_train['user_id']==1) & (user_action_train['spu_id']==j)].sort_values(by='date')
#      11         if act.head(1).action_type.values == 0:
#      12             count = count + 1
#
# C:\Users\luguangcheng\Anaconda2\lib\site-packages\pandas\core\ops.pyc in wrapper(self, other, axis)
#     761                 other = np.asarray(other)
#     762
# --> 763             res = na_op(values, other)
#     764             if isscalar(res):
#     765                 raise TypeError('Could not compare %s type with Series' %
#
# C:\Users\luguangcheng\Anaconda2\lib\site-packages\pandas\core\ops.pyc in na_op(x, y)
#     689             # we would allow datetime64 (but viewed as i8) against
#     690             # integer comparisons
# --> 691             if is_datetimelike_v_numeric(x, y):
#     692                 raise TypeError("invalid type comparison")
#     693
#
# C:\Users\luguangcheng\Anaconda2\lib\site-packages\pandas\core\common.pyc in is_datetimelike_v_numeric(a, b)
#    1640
#    1641     is_datetimelike = needs_i8_conversion
# -> 1642     return ((is_datetimelike(a) and is_numeric(b)) or
#    1643             (is_datetimelike(b) and is_numeric(a)))
#    1644
#
# C:\Users\luguangcheng\Anaconda2\lib\site-packages\pandas\core\common.pyc in needs_i8_conversion(arr_or_dtype)
#    1663
#    1664 def needs_i8_conversion(arr_or_dtype):
# -> 1665     return (is_datetime_or_timedelta_dtype(arr_or_dtype) or
#    1666             is_datetime64tz_dtype(arr_or_dtype))
#    1667
#
# C:\Users\luguangcheng\Anaconda2\lib\site-packages\pandas\core\common.pyc in is_datetime_or_timedelta_dtype(arr_or_dtype)
#    1602 def is_datetime_or_timedelta_dtype(arr_or_dtype):
#    1603     tipo = _get_dtype_type(arr_or_dtype)
# -> 1604     return issubclass(tipo, (np.datetime64, np.timedelta64))
#    1605
#    1606
#
# KeyboardInterrupt:

# %%
df = user_goods_action_train_sort
df = df[(df['date_num'] >= 1) & (df['date_num'] < 3)]
print len(df)
df_buy = df[df['action_type']==1]
print len(df_buy)
df_buy = df_buy[['user_id','spu_id']]
df_buy_act = pd.merge(df_buy, df, how='left', on=['user_id','spu_id'])
df_buy_act = df_buy_act[['user_id','spu_id','action_type']]
df_buy_act = df_buy_act.drop_duplicates(['user_id','spu_id'])
df_buy_act = df_buy_act[['user_id','action_type']].groupby(['user_id'],as_index=False).sum()
user_feature = pd.merge(user_feature,df_buy_act,how = 'left',on='user_id')
user_feature.fillna(0)
user_feature['buy_getian']= user_feature['buy']- user_feature['action_type']
user_feature['buy_getian_ratio'] =  user_feature['buy_getian']/user_feature['buy']
df_buy_act
# Out:
# 865141
# 6871
#       user_id  action_type
# 0         102            1
# 1         116            2
# 2         126            3
# 3         303            2
# 4         525            1
# 5         675            1
# 6         734            1
# 7         869            2
# 8        1111            1
# 9        1185            1
# 10       1221            1
# 11       1481            2
# 12       1511            1
# 13       1521            1
# 14       1677            4
# 15       1683            3
# 16       1748            1
# 17       1774            1
# 18       1945            1
# 19       2070            2
# 20       2117            1
# 21       2137            1
# 22       2204            1
# 23       2522            1
# 24       2545            1
# 25       3069            1
# 26       3207            3
# 27       3650            1
# 28       3976            1
# 29       4375            1
# ...       ...          ...
# 4368   645903            1
# 4369   645911            1
# 4370   645913            1
# 4371   645954            2
# 4372   646078            1
# 4373   646170            1
# 4374   646220            1
# 4375   646232            2
# 4376   646304            1
# 4377   646410            1
# 4378   646498            1
# 4379   646583            1
# 4380   646735            1
# 4381   646786            3
# 4382   646791            2
# 4383   646939            1
# 4384   647084            1
# 4385   647200            3
# 4386   647268            1
# 4387   647444            1
# 4388   647633            2
# 4389   647735            1
# 4390   647838            1
# 4391   647940            1
# 4392   648209            2
# 4393   648426            1
# 4394   648456            2
# 4395   649300            1
# 4396   649519            1
# 4397   649603            2
#
# [4398 rows x 2 columns]
